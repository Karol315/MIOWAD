# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from nn.network import SimpleNetwork
from nn.metrics import mse

# %%
train_data = pd.read_csv('../datasets/regression/square-simple-training.csv')


x_train = train_data['x']
y_train = train_data['y']


x_train_min = x_train.min()
x_train_max = x_train.max()
y_train_min = y_train.min()
y_train_max = y_train.max()

x_train_normalized = (x_train - x_train_min) / (x_train_max - x_train_min)

# %%
network = SimpleNetwork(
    input_size=1,
    hidden_layers_sizes=[5],
    output_size=1
)

# %%
y_train_pred = []
for i in range(len(train_data['x'])):
    y_train_pred.append(
        network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, c ='blue')
plt.scatter(x_train, y_train_pred, c ='red')
plt.show()

mse(y_train, y_train_pred)
# Out:
# array([44801.01581314])

# %%
network.hidden_layers[0].set_weights([   [-17.041677 ],
                                         [-42.277992 ],
                                         [-12.716685 ],
                                         [ -2.9805634],
                                         [ 35.923325 ]])

network.hidden_layers[0].set_bias([ 11.1751,  43.3852,  11.2032,   1.6433, -19.0130])

network.output_layer.set_weights([[ -4.628575,  -10.532224,   -6.708138,   20.003542,    3.5743825]])

network.output_layer.set_bias( [5.4565])

# %%
y_train_pred = []
for i in range(len(train_data['x'])):
    y_train_pred.append(
        network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, c ='blue')
plt.scatter(x_train, y_train_pred, c ='red')
plt.show()

mse(y_train, y_train_pred)[0]
# Out:
# np.float64(4.804209980483488)

# %%
test_data = pd.read_csv('../datasets/regression/square-simple-test.csv')

x_test = test_data['x']
y_test = test_data['y']

x_test_normalized = (x_test - x_train_min) / (x_train_max - x_train_min)

y_test_pred = []
for i in range(len(test_data['x'])):
    y_test_pred.append(
        network.predict(inputs = x_test_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, c ='blue')
plt.scatter(x_test, y_test_pred, c ='red')
plt.show()

mse(y_test, y_test_pred)
# Out:
# array([7.80619147])

# %%
train_data = pd.read_csv('../datasets/regression/steps-large-training.csv')

#normalizacja
x_train = train_data['x']
y_train = train_data['y']


x_train_min = x_train.min()
x_train_max = x_train.max()
y_train_min = y_train.min()
y_train_max = y_train.max()

x_train_normalized = (x_train - x_train_min) / (x_train_max - x_train_min)
y_train_normalized = (y_train - y_train_min) / (y_train_max - y_train_min)

# %%
y_train_pred = []
for i in range(len(train_data['x'])):
    y_train_pred.append(
        network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, c ='blue')
plt.scatter(x_train, y_train_pred, c ='red')
plt.show()

# %%
network.hidden_layers[0].set_weights([[ 746.5839   ],
 [-582.9855   ],
 [  -2.1919196],
 [   3.2751026],
 [1159.7727   ]])

network.hidden_layers[0].set_bias([-426.3555,  502.8300,   17.8853,   14.7611, -328.1114])

network.output_layer.set_weights([[  1.3866621, -20.374657,   -3.036112,    3.9852638,  19.355583 ]])

network.output_layer.set_bias( [-0.6240])

# %%
y_train_pred = []
for i in range(len(train_data['x'])):
    y_train_pred.append(
        network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, c ='blue')
plt.scatter(x_train, y_train_pred, c ='red')
plt.show()

mse(y_train, y_train_pred)
# Out:
# array([7.50476989])

# %%
test_data = pd.read_csv('../datasets/regression/steps-large-test.csv')

x_test = test_data['x']
y_test = test_data['y']

x_test_normalized = (x_test - x_train_min) / (x_train_max - x_train_min)

y_test_pred = []
for i in range(len(test_data['x'])):
    y_test_pred.append(
        network.predict(inputs = x_test_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, c ='blue')
plt.scatter(x_test, y_test_pred, c ='red')
plt.show()

mse(y_test, y_test_pred)
# Out:
# array([6.97656582])
