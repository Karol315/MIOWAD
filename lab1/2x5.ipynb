# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from nn.network import SimpleNetwork
from nn.metrics import mse

# %%
train_data = pd.read_csv('../datasets/regression/square-simple-training.csv')


x_train = train_data['x']
y_train = train_data['y']


x_train_min = x_train.min()
x_train_max = x_train.max()
y_train_min = y_train.min()
y_train_max = y_train.max()

x_train_normalized = (x_train - x_train_min) / (x_train_max - x_train_min)

# %%
network = SimpleNetwork(
    input_size=1,
    hidden_layers_sizes=[5, 5],
    output_size=1
)

# %%
y_train_pred = []
for i in range(len(train_data['x'])):
    y_train_pred.append(
        network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, c ='blue')
plt.scatter(x_train, y_train_pred, c ='red')
plt.show()

# %%
network.hidden_layers[0].set_weights([   [ 43.270123 ],
 [  1.5178739],
 [ -6.8554206],
 [ -9.486625 ],
 [-17.832611 ],
 [-25.31842  ],
 [-15.340255 ],
 [ -5.2985363],
 [-34.161713 ],
 [-12.389135 ]])

network.hidden_layers[0].set_bias([-46.7767,   4.0806,   1.8688,   8.9573,  -2.2303,  10.5637,  19.4428,
          1.1808,  16.2223,   7.1418])

network.output_layer.set_weights([[78.9951,     2.9728363,  3.4749765, -4.966697,   3.753383,   6.87271,
  -2.6588476,  3.3066335, -6.4894667, -4.538121 ]])

network.output_layer.set_bias( [3.3432])

# %%
y_train_pred = []
for i in range(len(train_data['x'])):
    y_train_pred.append(
        network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, c ='blue')
plt.scatter(x_train, y_train_pred, c ='red')
plt.show()

mse(y_train, y_train_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 y_train_pred = []
#       2 for i in range(len(train_data['x'])):
#       3     y_train_pred.append(
# ----> 4         network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
#       5                   )
#       6 plt.figure(figsize=(10, 6))
#       7 plt.scatter(x_train, y_train, c ='blue')
#
# File ~\Desktop\MIOWAD\nn\network.py:30, in SimpleNetwork.predict(self, inputs)
#      27 for layer in self.hidden_layers:
#      28     current_inputs = layer.forward(current_inputs)
# ---> 30 output = self.output_layer.forward(current_inputs)
#      31 return output
#
# File ~\Desktop\MIOWAD\nn\layer.py:13, in Layer.forward(self, inputs)
#      12 def forward(self, inputs):
# ---> 13     self.outputs = np.array([neuron.forward(inputs) for neuron in self.neurons])
#      14     return self.outputs
#
# File ~\Desktop\MIOWAD\nn\neuron.py:16, in Neuron.forward(self, inputs)
#      14 def forward(self, inputs):
#      15     inputs = np.asarray(inputs)
# ---> 16     self.output = self.activation(np.dot(self.weights, inputs) + self.bias)
#      17     return self.output
#
# ValueError: shapes (10,) and (5,1) not aligned: 10 (dim 0) != 5 (dim 0)

# %%
test_data = pd.read_csv('../datasets/regression/square-simple-test.csv')

x_test = test_data['x']
y_test = test_data['y']

x_test_normalized = (x_test - x_train_min) / (x_train_max - x_train_min)

y_test_pred = []
for i in range(len(test_data['x'])):
    y_test_pred.append(
        network.predict(inputs = x_test_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, c ='blue')
plt.scatter(x_test, y_test_pred, c ='red')
plt.show()

mse(y_test, y_test_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 11
#       8 y_test_pred = []
#       9 for i in range(len(test_data['x'])):
#      10     y_test_pred.append(
# ---> 11         network.predict(inputs = x_test_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
#      12                   )
#      13 plt.figure(figsize=(10, 6))
#      14 plt.scatter(x_test, y_test, c ='blue')
#
# File ~\Desktop\MIOWAD\nn\network.py:30, in SimpleNetwork.predict(self, inputs)
#      27 for layer in self.hidden_layers:
#      28     current_inputs = layer.forward(current_inputs)
# ---> 30 output = self.output_layer.forward(current_inputs)
#      31 return output
#
# File ~\Desktop\MIOWAD\nn\layer.py:13, in Layer.forward(self, inputs)
#      12 def forward(self, inputs):
# ---> 13     self.outputs = np.array([neuron.forward(inputs) for neuron in self.neurons])
#      14     return self.outputs
#
# File ~\Desktop\MIOWAD\nn\neuron.py:16, in Neuron.forward(self, inputs)
#      14 def forward(self, inputs):
#      15     inputs = np.asarray(inputs)
# ---> 16     self.output = self.activation(np.dot(self.weights, inputs) + self.bias)
#      17     return self.output
#
# ValueError: shapes (10,) and (5,1) not aligned: 10 (dim 0) != 5 (dim 0)

# %%
train_data = pd.read_csv('../datasets/regression/steps-large-training.csv')

#normalizacja
x_train = train_data['x']
y_train = train_data['y']


x_train_min = x_train.min()
x_train_max = x_train.max()
y_train_min = y_train.min()
y_train_max = y_train.max()

x_train_normalized = (x_train - x_train_min) / (x_train_max - x_train_min)
y_train_normalized = (y_train - y_train_min) / (y_train_max - y_train_min)

# %%
network.hidden_layers[0].set_weights([   [ 43.270123 ],
 [  1.5178739],
 [ -6.8554206],
 [ -9.486625 ],
 [-17.832611 ],
 [-25.31842  ],
 [-15.340255 ],
 [ -5.2985363],
 [-34.161713 ],
 [-12.389135 ]])

network.hidden_layers[0].set_bias([-46.7767,   4.0806,   1.8688,   8.9573,  -2.2303,  10.5637,  19.4428,
          1.1808,  16.2223,   7.1418])

network.output_layer.set_weights([[78.9951,     2.9728363,  3.4749765, -4.966697,   3.753383,   6.87271,
  -2.6588476,  3.3066335, -6.4894667, -4.538121 ]])

network.output_layer.set_bias( [3.3432])

# %%
y_train_pred = []
for i in range(len(train_data['x'])):
    y_train_pred.append(
        network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, c ='blue')
plt.scatter(x_train, y_train_pred, c ='red')
plt.show()

mse(y_train, y_train_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 y_train_pred = []
#       2 for i in range(len(train_data['x'])):
#       3     y_train_pred.append(
# ----> 4         network.predict(inputs = x_train_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
#       5                   )
#       6 plt.figure(figsize=(10, 6))
#       7 plt.scatter(x_train, y_train, c ='blue')
#
# File ~\Desktop\MIOWAD\nn\network.py:30, in SimpleNetwork.predict(self, inputs)
#      27 for layer in self.hidden_layers:
#      28     current_inputs = layer.forward(current_inputs)
# ---> 30 output = self.output_layer.forward(current_inputs)
#      31 return output
#
# File ~\Desktop\MIOWAD\nn\layer.py:13, in Layer.forward(self, inputs)
#      12 def forward(self, inputs):
# ---> 13     self.outputs = np.array([neuron.forward(inputs) for neuron in self.neurons])
#      14     return self.outputs
#
# File ~\Desktop\MIOWAD\nn\neuron.py:16, in Neuron.forward(self, inputs)
#      14 def forward(self, inputs):
#      15     inputs = np.asarray(inputs)
# ---> 16     self.output = self.activation(np.dot(self.weights, inputs) + self.bias)
#      17     return self.output
#
# ValueError: shapes (10,) and (5,1) not aligned: 10 (dim 0) != 5 (dim 0)

# %%
test_data = pd.read_csv('../datasets/regression/steps-large-test.csv')

x_test = test_data['x']
y_test = test_data['y']

x_test_normalized = (x_test - x_train_min) / (x_train_max - x_train_min)

y_test_pred = []
for i in range(len(test_data['x'])):
    y_test_pred.append(
        network.predict(inputs = x_test_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
                  )
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, c ='blue')
plt.scatter(x_test, y_test_pred, c ='red')
plt.show()

mse(y_test, y_test_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 11
#       8 y_test_pred = []
#       9 for i in range(len(test_data['x'])):
#      10     y_test_pred.append(
# ---> 11         network.predict(inputs = x_test_normalized[i])[0] * (y_train_max - y_train_min) + y_train_min
#      12                   )
#      13 plt.figure(figsize=(10, 6))
#      14 plt.scatter(x_test, y_test, c ='blue')
#
# File ~\Desktop\MIOWAD\nn\network.py:30, in SimpleNetwork.predict(self, inputs)
#      27 for layer in self.hidden_layers:
#      28     current_inputs = layer.forward(current_inputs)
# ---> 30 output = self.output_layer.forward(current_inputs)
#      31 return output
#
# File ~\Desktop\MIOWAD\nn\layer.py:13, in Layer.forward(self, inputs)
#      12 def forward(self, inputs):
# ---> 13     self.outputs = np.array([neuron.forward(inputs) for neuron in self.neurons])
#      14     return self.outputs
#
# File ~\Desktop\MIOWAD\nn\neuron.py:16, in Neuron.forward(self, inputs)
#      14 def forward(self, inputs):
#      15     inputs = np.asarray(inputs)
# ---> 16     self.output = self.activation(np.dot(self.weights, inputs) + self.bias)
#      17     return self.output
#
# ValueError: shapes (10,) and (5,1) not aligned: 10 (dim 0) != 5 (dim 0)

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"Is CUDA available: {torch.cuda.is_available()}")
# Out:
# PyTorch version: 2.10.0+cpu
# Is CUDA available: False
